# %%
import requests
import json
import pandas as pd

# %%
def fetch_data():
    url = 'https://api.coingecko.com/api/v3/coins/markets?vs_currency=usd&ids=bitcoin%2Cethereum%2Cripple%2Ctether%2Cbinancecoin%2Clitecoin%2Ccardano%2Cpolkadot%2Cchainlink%2Cstellar&order=market_cap_desc&per_page=100&page=1&sparkline=false'
    response = requests.get(url)
    data = response.json()

    df = pd.DataFrame(data)

    df.to_csv('data.csv', index=False)

    return df

# %%
fetch_data()
# Out:
#             id symbol       name  \
# 0      bitcoin    btc    Bitcoin
# 1     ethereum    eth   Ethereum
# 2       tether   usdt     Tether
# 3  binancecoin    bnb        BNB
# 4       ripple    xrp        XRP
# 5      cardano    ada    Cardano
# 6     polkadot    dot   Polkadot
# 7     litecoin    ltc   Litecoin
# 8    chainlink   link  Chainlink
# 9      stellar    xlm    Stellar
#
#                                                image  current_price  \
# 0  https://assets.coingecko.com/coins/images/1/la...   22369.000000
# 1  https://assets.coingecko.com/coins/images/279/...    1570.230000
# 2  https://assets.coingecko.com/coins/images/325/...       1.000000
# 3  https://assets.coingecko.com/coins/images/825/...     290.040000
# 4  https://assets.coingecko.com/coins/images/44/l...       0.377356
# 5  https://assets.coingecko.com/coins/images/975/...       0.341988
# 6  https://assets.coingecko.com/coins/images/1217...       6.000000
# 7  https://assets.coingecko.com/coins/images/2/la...      89.790000
# 8  https://assets.coingecko.com/coins/images/877/...       6.920000
# 9  https://assets.coingecko.com/coins/images/100/...       0.085888
#
#      market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  431472687282                1             469288708899   21954000499
# 1  188990316195                2             188988302816    6993499401
# 2   71391922543                3              71391922543   27725770810
# 3   45797200691                4              58009604888     349302742
# 4   19204174099                6              37691521089     849946093
# 5   11979722683                8              15382713663     221392447
# 6    7249543771               14               7735171544     216062133
# 7    6493813392               16               7533569713     377034787
# 8    3401289618               24               6918815739     228409351
# 9    2268309465               31               4291274497      48264118
#
#        high_24h  ...  total_supply    max_supply           ath  \
# 0  22493.000000  ...  2.100000e+07  2.100000e+07  69045.000000
# 1   1579.870000  ...  1.204770e+08           NaN   4878.260000
# 2      1.005000  ...  7.135913e+10           NaN      1.320000
# 3    291.590000  ...  1.579002e+08  2.000000e+08    686.310000
# 4      0.380899  ...  9.998911e+10  1.000000e+11      3.400000
# 5      0.345190  ...  4.500000e+10  4.500000e+10      3.090000
# 6      6.080000  ...  1.289373e+09           NaN     54.980000
# 7     90.880000  ...  8.400000e+07  8.400000e+07    410.260000
# 8      7.010000  ...  1.000000e+09  1.000000e+09     52.700000
# 9      0.086152  ...  5.000179e+10  5.000179e+10      0.875563
#
#    ath_change_percentage                  ath_date        atl  \
# 0              -67.61011  2021-11-10T14:24:11.849Z  67.810000
# 1              -67.81452  2021-11-10T14:24:19.604Z   0.432979
# 2              -24.34285  2018-07-24T00:00:00.000Z   0.572521
# 3              -57.73266  2021-05-10T07:24:17.097Z   0.039818
# 4              -88.89786  2018-01-07T00:00:00.000Z   0.002686
# 5              -88.91330  2021-09-02T06:00:10.474Z   0.019253
# 6              -89.08152  2021-11-04T14:10:09.301Z   2.700000
# 7              -78.13800  2021-05-10T03:13:07.904Z   1.150000
# 8              -86.86879  2021-05-10T00:13:57.214Z   0.148183
# 9              -90.19184  2018-01-03T00:00:00.000Z   0.000476
#
#    atl_change_percentage                  atl_date  \
# 0            32880.16724  2013-07-06T00:00:00.000Z
# 1           362525.43253  2015-10-20T00:00:00.000Z
# 2               74.84358  2015-03-02T00:00:00.000Z
# 3           728429.18480  2017-10-19T00:00:00.000Z
# 4            13945.85180  2014-05-22T00:00:00.000Z
# 5             1677.59907  2020-03-13T02:22:55.044Z
# 6              122.54597  2020-08-20T05:48:11.359Z
# 7             7707.07716  2015-01-14T00:00:00.000Z
# 8             4569.69262  2017-11-29T00:00:00.000Z
# 9            17936.63163  2015-03-05T00:00:00.000Z
#
#                                                  roi              last_updated
# 0                                               None  2023-03-04T08:54:03.247Z
# 1  {'times': 92.86790526425325, 'currency': 'btc'...  2023-03-04T08:53:40.981Z
# 2                                               None  2023-03-04T08:50:14.045Z
# 3                                               None  2023-03-04T08:53:44.880Z
# 4                                               None  2023-03-04T08:54:01.674Z
# 5                                               None  2023-03-04T08:53:56.384Z
# 6                                               None  2023-03-04T08:54:03.186Z
# 7                                               None  2023-03-04T08:54:00.939Z
# 8                                               None  2023-03-04T08:53:42.516Z
# 9                                               None  2023-03-04T08:54:03.042Z
#
# [10 rows x 26 columns]
